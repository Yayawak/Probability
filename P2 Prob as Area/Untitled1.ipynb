# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=[6,6])
ax = plt.axes()
ax.grid()
x = np.arange(0,31,1)
y = np.exp2(x)
y2 = np.

ax.plot(x,y,c='r',ls='--')
ax.plot(x,y2,c='m')
# print(y2)
